# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import string

import spacy
import re
import string
spacy.load('en')
nlp = spacy.load("en")

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import text 

def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
# Movie 1 - An Inconvenient Truth #

## Grab text, and parse ##
url = 'https://archive.org/stream/AnInconvenientTruth_201607/An%20Inconvenient%20Truth_djvu.txt' 

response = requests.get(url)

page = response.text
soup = BeautifulSoup(page, "lxml")

movie1_text = soup.find('div', {"class": "container container-ia"}).find('pre').text
movie1 = movie1_text.partition('http://arakanindobhasaa.blogspot.com/')[2].partition('Download Film \n\nhttp://rarbg.com/torrents/filmi/download/2d800b47328044b65bc3641cc98c0f78d4650b81/torren')[0]
movie1 = movie1.replace('\n', '').replace("\'", "'")
movie1 = movie1.lower()

# Replace all A1's with AL so that AL GORE shows up
movie1 = movie1.replace("a1", "al")
movie1 = movie1.replace("global warming", "globalwarming")
movie1 = movie1.replace("al gore", "algore")
movie1 = movie1.replace("donald trump", "donaldtrump")
movie1 = movie1.replace("climate change", "climatechange")
movie1 = movie1.replace("global warming", "globalwarming")

## Create List of Sentences ##
doc = nlp(movie1)
# doc.sents is a generator that yields sentence spans
doc_list = [sent.text for sent in doc.sents]
# ['This is a sentence.', 'This is another one.']

# Make everything lowercase
#doc_list_edit = [sentence.lower() for sentence in doc_list]

# Remove Numbers
doc_list_edit = [re.sub(r'\d+', '', sentence) for sentence in doc_list]

# Remove Punctuation
translator = str.maketrans('', '', string.punctuation)
movie1_list = [sentence.translate(translator) for sentence in doc_list_edit]

# %%
# Movie 2 - An Inconvenient Sequel: Truth to Power #

## Grab text, and parse ##
url2 = 'https://springfieldspringfield.co.uk/movie_script.php?movie=an-inconvenient-sequel-truth-to-power' 
response2 = requests.get(url2)

page2 = response2.text
soup2 = BeautifulSoup(page2, "lxml")

movie2_text = soup2.find('div', {"class": "scrolling-script-container"}).text
movie2 = movie2_text.replace('\n', '').replace("\'", "'")
movie2 = movie2.lower()

# Replace some strings
movie2 = movie2.replace("a1", "al")
movie2 = movie2.replace("global warming", "globalwarming")
movie2 = movie2.replace("al gore", "algore")
movie2 = movie2.replace("donald trump", "donaldtrump")
movie2 = movie2.replace("climate change", "climatechange")
movie2 = movie2.replace("global warming", "globalwarming")

## Create List of Sentences ##
doc2 = nlp(movie2)
# doc.sents is a generator that yields sentence spans
doc_list2 = [sent.text for sent in doc2.sents]
# ['This is a sentence.', 'This is another one.']

# Make everything lowercase
#doc_list_edit2 = [sentence.lower() for sentence in doc_list2]

# Remove Numbers
doc_list_edit2 = [re.sub(r'\d+', '', sentence) for sentence in doc_list2]

# Remove Punctuation
translator = str.maketrans('', '', string.punctuation)
movie2_list = [sentence.translate(translator) for sentence in doc_list_edit2]

# %% [markdown]
# # Playing around with stop words

# %%
df_stop = pd.read_csv("/Users/JacKuo14/Documents/Metis/course_work/project04_climate/news-stopwords/sw1k.csv")
df_stop['ratio'] = df_stop['frequency'] / df_stop['presence']
df_stop = df_stop.sort_values(by = 'ratio', ascending = False).reset_index(drop = True)
news_stop_list = df_stop['term'].to_list()

# %%
## Topic Modeling ##

movie_list_full = movie1_list + movie2_list

more_stop_words = ['lot', 'dont', 'im', 'didnt', 'hey', 'lets', 'itll', 'yeah', 'heres', 'theyre', 'youre', 'said', 'went', 'came', 'look', 'gone', 'gonna', 'actually', 'really', 'like', 'just', 'thats', 'theres', 'used', 'oh', 'uh', 'ive']
stop_words_full = text.ENGLISH_STOP_WORDS.union(more_stop_words + news_stop_list)

# Count Vectorizing #
vectorizer = CountVectorizer(stop_words = stop_words_full, min_df = 5, max_df = .3)
fit_doc = vectorizer.fit_transform(movie_list_full)
df_doc = pd.DataFrame(fit_doc.toarray(), columns = vectorizer.get_feature_names())

num = 7

## NMF ##
nmf_model = NMF(num)
doc_topic = nmf_model.fit_transform(fit_doc)

component_list = ["component_" + str(val) for val in range(1, num+1)]

topic_word = pd.DataFrame(nmf_model.components_.round(num),
             index = component_list, columns = vectorizer.get_feature_names())
#topic_word3

# %%
display_topics(nmf_model, vectorizer.get_feature_names(), 50)
# Out:
# Topic  0
# ice, ocean, floating, shelf, arctic, cap, formed, difference, glacier, antarctica, mass, greenland, raise, relatively, scientists, measured, measure, surface, friend, warmer, cold, theyve, planet, patterns, feet, melting, completely, effect, glaciers, warm, cities, absolutely, parts, massive, warming, sort, conditions, greenhouse, scientific, temperature, northern, pattern, wind, sea, atlantic, temperatures, heat, whats, happening, isnt
#
# Topic  1
# earth, picture, planet, sun, keeps, atmosphere, ability, temperature, apollo, balance, earths, looked, blue, completely, cities, civilization, friend, relatively, welcome, generation, environment, melting, satellite, bush, effect, mass, surface, thinking, remember, pattern, century, deep, burning, brings, formed, scientists, climatechange, paris, layer, vice, environmental, climate, consequences, alltime, worse, population, warm, arctic, patterns, science
#
# Topic  2
# movement, environmental, picture, moral, solve, apollo, crisis, remember, cars, guy, vice, democracy, layer, blue, looked, greenland, downpour, dioxide, drought, earth, greenhouse, everybody, earths, effect, electricity, emissions, environment, globalwarming, glaciers, gore, fair, extremely, farm, feet, figure, fit, glacier, developing, generation, floating, flooding, florida, formed, fossil, friend, gas, difference, zero, despair, arctic
#
# Topic  3
# globalwarming, pollution, drought, storm, flooding, causes, scientific, arctic, yes, stronger, coal, scientists, storms, oceans, paris, truth, science, massive, cities, effect, pattern, moral, brings, maybe, heat, hottest, friend, temperature, reasons, worldwide, electricity, layer, atmosphere, downpour, conditions, sir, puts, sea, warm, greenland, theyve, warmer, whats, training, atlantic, consequences, ocean, cap, natural, alltime
#
# Topic  4
# climate, crisis, paris, solve, solving, scientists, climatechange, environmental, agreement, yes, weve, deep, speak, earths, balance, nations, despair, storm, moral, zero, gas, stuff, oil, heat, training, democracy, coal, conditions, satellite, caused, sort, pattern, planet, truth, layer, hear, fossil, generation, id, accept, downpour, sir, isnt, consequences, greenhouse, orleans, absolutely, emissions, guy, cars
#
# Topic  5
# solar, wind, electricity, paris, utility, ocean, parts, storms, fossil, storm, worldwide, wow, seeing, denial, relatively, gas, temperature, warmer, patterns, basis, hear, damage, oil, stronger, caused, formed, climatechange, yes, sea, agreement, temperatures, degrees, generation, emissions, oceans, truth, conditions, cars, atlantic, id, accept, nations, isnt, blue, cold, downpour, arctic, causes, training, consequences
#
# Topic  6
# atmosphere, carbon, dioxide, coal, sun, northern, temperature, earths, heat, gas, oil, pollution, layer, burning, warmer, measure, renewables, parts, renewable, electricity, emissions, anymore, reasons, oceans, cars, planet, worldwide, temperatures, whats, developing, scientists, friend, degrees, zero, civilization, pattern, ocean, basis, massive, greenland, theyve, happening, cities, agreement, arctic, alltime, atlantic, greenhouse, hear, everybody

# %%
H.head()
# Out:
#                                               ice  earth  movement  \
#  you look at that river                       0.0    0.0       0.0
# gently flowing by                             0.0    0.0       0.0
# you notice the leaves rustling with the wind  0.0    0.0       0.0
# you hear the birds                            0.0    0.0       0.0
# you hear the tree frogs                       0.0    0.0       0.0
#
#                                               globalwarming  climate    solar  \
#  you look at that river                                 0.0  0.00000  0.00000
# gently flowing by                                       0.0  0.00000  0.00000
# you notice the leaves rustling with the wind            0.0  0.00000  0.17305
# you hear the birds                                      0.0  0.00224  0.00773
# you hear the tree frogs                                 0.0  0.00224  0.00773
#
#                                               atmosphere  topic  movie
#  you look at that river                          0.00000   none      1
# gently flowing by                                0.00000   none      1
# you notice the leaves rustling with the wind     0.00000  solar      1
# you hear the birds                               0.00497  solar      1
# you hear the tree frogs                          0.00497  solar      1

# %% [markdown]
# # Comparing Global Warming with Climate Change

# %%
H2 = pd.DataFrame(doc_topic.round(7), index = movie_list_full, columns = component_list)

# Add Movie Column
m1_len = [1] * len(movie1_list)
m2_len = [2] * len(movie2_list)
m12_len = m1_len + m2_len
H2['movie'] = m12_len

# %%
H2.sort_values(by = 'component_5', ascending = False)[:10]
# Out:
#                                                     component_1  component_2  \
# you know anybody who decides to be a part of he...          0.0          0.0
# i do my best to speak for the public interest i...          0.0          0.0
# if we increase the fraction of that that we har...          0.0          0.0
# this movement to solve the climate crisis is in...          0.0          0.0
# we had a real opportunity to start building eno...          0.0          0.0
# as you know i have this passion for solving the...          0.0          0.0
# it is frustrating that for many years ive tried...          0.0          0.0
# every storm is different now because of the cli...          0.0          0.0
# what a blessing it was that pope francis came t...          0.0          0.0
# sometimes it seems to me that the climate crisi...          0.0          0.0
#
#                                                     component_3  component_4  \
# you know anybody who decides to be a part of he...     0.016490      0.00000
# i do my best to speak for the public interest i...     0.000000      0.00000
# if we increase the fraction of that that we har...     0.016817      0.00000
# this movement to solve the climate crisis is in...     0.883837      0.00020
# we had a real opportunity to start building eno...     0.000000      0.00000
# as you know i have this passion for solving the...     0.000000      0.00000
# it is frustrating that for many years ive tried...     0.000000      0.00000
# every storm is different now because of the cli...     0.000000      0.01492
# what a blessing it was that pope francis came t...     0.000000      0.00000
# sometimes it seems to me that the climate crisi...     0.000000      0.00000
#
#                                                     component_5  component_6  \
# you know anybody who decides to be a part of he...     0.597418     0.000000
# i do my best to speak for the public interest i...     0.596754     0.000000
# if we increase the fraction of that that we har...     0.580822     0.000000
# this movement to solve the climate crisis is in...     0.579156     0.000000
# we had a real opportunity to start building eno...     0.577852     0.000000
# as you know i have this passion for solving the...     0.577852     0.000000
# it is frustrating that for many years ive tried...     0.554441     0.000000
# every storm is different now because of the cli...     0.549101     0.006171
# what a blessing it was that pope francis came t...     0.547300     0.000000
# sometimes it seems to me that the climate crisi...     0.533175     0.000000
#
#                                                     component_7  movie
# you know anybody who decides to be a part of he...          0.0      2
# i do my best to speak for the public interest i...          0.0      2
# if we increase the fraction of that that we har...          0.0      2
# this movement to solve the climate crisis is in...          0.0      2
# we had a real opportunity to start building eno...          0.0      2
# as you know i have this passion for solving the...          0.0      2
# it is frustrating that for many years ive tried...          0.0      2
# every storm is different now because of the cli...          0.0      2
# what a blessing it was that pope francis came t...          0.0      2
# sometimes it seems to me that the climate crisi...          0.0      2

# %%
H2.sort_values(by = 'component_6', ascending = False)[:15]
# Out:
#                                                                                                       component_1  \
# and it resulted in the largest solar loan in the history of the world to help india move forward ...          0.0
# but in many parts of china it is already cheaper to get electricity from solar and wind                       0.0
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...          0.0
# pennsylvanias exercising leadership on solar power and wind power                                             0.0
# and we want to create jobs in solar and wind and efficiency                                                   0.0
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...          0.0
# so my narrow interest is a way around these high interest rates that the indians are so concerned...          0.0
# fourteen years ago the best projections available were that we would be able to install worldwide...          0.0
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...          0.0
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...          0.0
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...          0.0
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...          0.0
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...          0.0
# the new administration they didnt really realize they were also canceling this solar storm earlyw...          0.0
# now were seeing this instead solar panels                                                                     0.0
#
#                                                                                                       component_2  \
# and it resulted in the largest solar loan in the history of the world to help india move forward ...      0.00000
# but in many parts of china it is already cheaper to get electricity from solar and wind                   0.00000
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...      0.00000
# pennsylvanias exercising leadership on solar power and wind power                                         0.00000
# and we want to create jobs in solar and wind and efficiency                                               0.00000
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...      0.00000
# so my narrow interest is a way around these high interest rates that the indians are so concerned...      0.00000
# fourteen years ago the best projections available were that we would be able to install worldwide...      0.00000
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...      0.00000
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...      0.00000
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...      0.00000
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...      0.00000
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...      0.00326
# the new administration they didnt really realize they were also canceling this solar storm earlyw...      0.00000
# now were seeing this instead solar panels                                                                 0.00000
#
#                                                                                                       component_3  \
# and it resulted in the largest solar loan in the history of the world to help india move forward ...          0.0
# but in many parts of china it is already cheaper to get electricity from solar and wind                       0.0
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...          0.0
# pennsylvanias exercising leadership on solar power and wind power                                             0.0
# and we want to create jobs in solar and wind and efficiency                                                   0.0
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...          0.0
# so my narrow interest is a way around these high interest rates that the indians are so concerned...          0.0
# fourteen years ago the best projections available were that we would be able to install worldwide...          0.0
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...          0.0
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...          0.0
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...          0.0
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...          0.0
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...          0.0
# the new administration they didnt really realize they were also canceling this solar storm earlyw...          0.0
# now were seeing this instead solar panels                                                                     0.0
#
#                                                                                                       component_4  \
# and it resulted in the largest solar loan in the history of the world to help india move forward ...     0.000000
# but in many parts of china it is already cheaper to get electricity from solar and wind                  0.000000
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...     0.000000
# pennsylvanias exercising leadership on solar power and wind power                                        0.000000
# and we want to create jobs in solar and wind and efficiency                                              0.000000
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...     0.000000
# so my narrow interest is a way around these high interest rates that the indians are so concerned...     0.000000
# fourteen years ago the best projections available were that we would be able to install worldwide...     0.009817
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...     0.007897
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...     0.000000
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...     0.000000
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...     0.001372
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...     0.006725
# the new administration they didnt really realize they were also canceling this solar storm earlyw...     0.018103
# now were seeing this instead solar panels                                                                0.000000
#
#                                                                                                       component_5  \
# and it resulted in the largest solar loan in the history of the world to help india move forward ...     0.000000
# but in many parts of china it is already cheaper to get electricity from solar and wind                  0.000000
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...     0.000000
# pennsylvanias exercising leadership on solar power and wind power                                        0.000000
# and we want to create jobs in solar and wind and efficiency                                              0.000000
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...     0.000000
# so my narrow interest is a way around these high interest rates that the indians are so concerned...     0.000000
# fourteen years ago the best projections available were that we would be able to install worldwide...     0.000000
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...     0.000000
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...     0.000000
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...     0.000000
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...     0.000000
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...     0.044470
# the new administration they didnt really realize they were also canceling this solar storm earlyw...     0.007718
# now were seeing this instead solar panels                                                                0.000000
#
#                                                                                                       component_6  \
# and it resulted in the largest solar loan in the history of the world to help india move forward ...     0.725333
# but in many parts of china it is already cheaper to get electricity from solar and wind                  0.619793
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...     0.535777
# pennsylvanias exercising leadership on solar power and wind power                                        0.535777
# and we want to create jobs in solar and wind and efficiency                                              0.535777
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...     0.535777
# so my narrow interest is a way around these high interest rates that the indians are so concerned...     0.535777
# fourteen years ago the best projections available were that we would be able to install worldwide...     0.437431
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...     0.430064
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...     0.428592
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...     0.423523
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...     0.421584
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...     0.408556
# the new administration they didnt really realize they were also canceling this solar storm earlyw...     0.380368
# now were seeing this instead solar panels                                                                0.377764
#
#                                                                                                       component_7  \
# and it resulted in the largest solar loan in the history of the world to help india move forward ...     0.000000
# but in many parts of china it is already cheaper to get electricity from solar and wind                  0.028547
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...     0.000000
# pennsylvanias exercising leadership on solar power and wind power                                        0.000000
# and we want to create jobs in solar and wind and efficiency                                              0.000000
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...     0.000000
# so my narrow interest is a way around these high interest rates that the indians are so concerned...     0.000000
# fourteen years ago the best projections available were that we would be able to install worldwide...     0.021461
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...     0.000000
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...     0.000000
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...     0.000000
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...     0.008960
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...     0.000000
# the new administration they didnt really realize they were also canceling this solar storm earlyw...     0.000000
# now were seeing this instead solar panels                                                                0.000000
#
#                                                                                                       movie
# and it resulted in the largest solar loan in the history of the world to help india move forward ...      2
# but in many parts of china it is already cheaper to get electricity from solar and wind                   2
# well in the us in calendar year uh  if you look at the investments in the us in the building of n...      2
# pennsylvanias exercising leadership on solar power and wind power                                         1
# and we want to create jobs in solar and wind and efficiency                                               2
# when india goes to borrow money to build solar farms or wind farms they have to pay  plus an fx u...      2
# so my narrow interest is a way around these high interest rates that the indians are so concerned...      2
# fourteen years ago the best projections available were that we would be able to install worldwide...      2
# and one was the crucial earlywarning device for solar storms that threaten electric utility grids...      2
#  and they have lobbied the state legislature to basically make it illegal to lease a solar panel ...      2
# utility monopolies really really fear disruption and have woken up and said wow this solar thing ...      2
# i think that the emergence of solar electricity as a competitive viable option it opens up a path...      2
# solarcity could be the corporate hero of paris by announcing that it will give the technology to ...      2
# the new administration they didnt really realize they were also canceling this solar storm earlyw...      2
# now were seeing this instead solar panels                                                                 2

# %% [markdown]
# # High Level, how much of each topic exists in each movie

# %%
df = H.groupby('movie').sum().round(1)

# %%
df.sum(axis=0)
# Out:
# ice              24.4
# earth            15.7
# movement          7.3
# globalwarming    20.0
# climate          21.4
# solar            16.8
# atmosphere       19.9
# dtype: float64

# %%
df2 = df.div(df.sum(axis=0), axis=1).round(2).transpose().reset_index().rename(columns = {'index' : 'topic', 1: 'Inconvenient Truth', 2: 'Inconvenient Sequel'})
df2
# Out:
# movie          topic  Inconvenient Truth  Inconvenient Sequel
# 0                ice                0.86                 0.14
# 1              earth                0.69                 0.31
# 2           movement                0.12                 0.88
# 3      globalwarming                0.66                 0.34
# 4            climate                0.16                 0.84
# 5              solar                0.20                 0.80
# 6         atmosphere                0.67                 0.33

# %%
df1 = df.div(df.sum(axis=0), axis=1).round(2)
df1['ice'].transpose()
# Out:
# movie
# 1    0.86
# 2    0.14
# Name: ice, dtype: float64

# %%
df3 = df2.sort_values(by = 'Inconvenient Truth', ascending = False)

# %%
df3
# Out:
# movie          topic  Inconvenient Truth  Inconvenient Sequel
# 0                ice                0.86                 0.14
# 1              earth                0.69                 0.31
# 6         atmosphere                0.67                 0.33
# 3      globalwarming                0.66                 0.34
# 5              solar                0.20                 0.80
# 4            climate                0.16                 0.84
# 2           movement                0.12                 0.88

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import rcParams

# %%
# plot

figure(num=None, figsize=(12, 10)) #dpi=80, facecolor='w', edgecolor='k')

barWidth = 0.85
names = ('Ice', 'Earth', 'Atmosphere', 'Global Warming', 'Solar', 'Climate', 'Movement')
r = [0, 1, 2, 3, 4, 5, 6]
# Create green Bars
plt.bar(r, df3['Inconvenient Truth'], color= '#00008b', edgecolor='white', width=barWidth, label = 'Inconvenient Truth - 2006')
# Create orange Bars
plt.bar(r, df3['Inconvenient Sequel'], bottom=df3['Inconvenient Truth'], color='#add8e6', edgecolor='white', width=barWidth, label = 'Inconvenient Sequel - 2017')
# Create blue Bars
#plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth)

#font = {'size'   : 25}
rcParams['mathtext.default'] = 'regular'
plt.xticks(size = 20)
plt.yticks(size = 20)

# Custom x axis
plt.xticks(r, names, rotation=70)
#plt.xlabel("group")
 
# Show graphic
plt.legend()
plt.show()
plt.savefig('topic_movie_comparison.png')

# %%
figure(num=None, figsize=(12, 10)) #dpi=80, facecolor='w', edgecolor='k')

barWidth = 0.85
names = ('Ice', 'Earth', 'Atmosphere', 'Global Warming', 'Solar', 'Climate', 'Movement')
r = [0, 1, 2, 3, 4, 5, 6]
# Create green Bars
plt.bar(r, df['Inconvenient Truth'], color= '#00008b', edgecolor='white', width=barWidth, label = 'Inconvenient Truth - 2006')
# Create orange Bars
plt.bar(r, df['Inconvenient Sequel'], bottom=df['Inconvenient Truth'], color='#add8e6', edgecolor='white', width=barWidth, label = 'Inconvenient Sequel - 2017')
# Create blue Bars
#plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color='#a3acff', edgecolor='white', width=barWidth)
 
# Custom x axis
plt.xticks(r, names, rotation=70)
#plt.xlabel("group")
 
# Show graphic
plt.legend()
plt.show()

# %%
df.transpose().reset_index().rename(columns = {'index' : 'topic', 1: 'Inconvenient Truth', 2: 'Inconvenient Sequel'}).sort_values(by = 'Inconvenient Truth', ascending = False)
# Out:
# movie          topic  Inconvenient Truth  Inconvenient Sequel
# 0                ice                20.9                  3.5
# 6         atmosphere                13.4                  6.5
# 3      globalwarming                13.1                  6.9
# 1              earth                10.8                  4.9
# 4            climate                 3.4                 18.0
# 5              solar                 3.4                 13.4
# 2           movement                 0.9                  6.4

# %%
fig, ax = plt.subplots(1,2, figsize=(10,10))
sns.barplot(x = 'topic', y = 'Inconvenient Truth', data = df2.sort_values(by = 'Inconvenient Truth', ascending = False), ax=ax[0])
sns.barplot(x = 'topic', y = 'Inconvenient Sequel', data = df2.sort_values(by = 'Inconvenient Sequel', ascending = False), ax=ax[1])
fig.show()



#sns.barplot(x = 'topic', y = 'Inconvenient Truth', data = df2)
#sns.barplot(x = 'topic', y = 'Inconvenient Sequel', data = df2)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
sns.barplot(x = 'topic', y = 'Inconvenient Truth', data = df2)
sns.barplot(x = 'topic', y = 'Inconvenient Sequel', data = df2)

# %%
fig, ax1 = pyplot.subplots(figsize=(10, 10))
tidy = df.melt(id_vars='topic').rename(columns=str.title)
seaborn.barplot(x='Topic', y='Value', hue='Variable', data=tidy, ax=ax1)

# %%
df_test = pd.DataFrame({
    'Factor': ['Growth', 'Value'],
    'Weight': [0.10, 0.20],
    'Variance': [0.15, 0.35]
})
df_test
# Out:
#    Factor  Weight  Variance
# 0  Growth     0.1      0.15
# 1   Value     0.2      0.35

# %%
df_test = pandas.DataFrame({
    'Factor': ['Growth', 'Value'],
    'Weight': [0.10, 0.20],
    'Variance': [0.15, 0.35]
})
fig, ax1 = pyplot.subplots(figsize=(10, 10))
tidy = df.melt(id_vars='Factor').rename(columns=str.title)
seaborn.barplot(x='Factor', y='Value', hue='Variable', data=tidy, ax=ax1)
seaborn.despine(fig)

# %%
df.head()
# Out:
#        component_1  component_2  component_3  component_4  component_5  \
# movie
# 1        20.916418    10.892435     0.913550    13.093958     3.428364
# 2         3.452632     4.957344     6.354202     6.863985    17.987741
#
#        component_6  component_7
# movie
# 1         3.397908    13.378412
# 2        13.394337     6.474320

# %%
H2.shape
# Out:
# (1900, 8)

# %% [markdown]
# # Count of each Category in each movie

# %%
H = pd.DataFrame(doc_topic.round(5), index = movie_list_full, columns = component_list)

H = H.rename(columns = {"component_1": "ice", 
                                     "component_2": "earth", 
                                     "component_3": "movement", 
                                     "component_4": "globalwarming", 
                                     "component_5": "climate", 
                                     "component_6": "solar", "component_7": "atmosphere"})


#H['topic'] = H.idxmax(axis=0)
H.head()
# Out:
#                                               ice  earth  movement  \
#  you look at that river                       0.0    0.0       0.0
# gently flowing by                             0.0    0.0       0.0
# you notice the leaves rustling with the wind  0.0    0.0       0.0
# you hear the birds                            0.0    0.0       0.0
# you hear the tree frogs                       0.0    0.0       0.0
#
#                                               globalwarming  climate    solar  \
#  you look at that river                                 0.0  0.00000  0.00000
# gently flowing by                                       0.0  0.00000  0.00000
# you notice the leaves rustling with the wind            0.0  0.00000  0.17305
# you hear the birds                                      0.0  0.00224  0.00773
# you hear the tree frogs                                 0.0  0.00224  0.00773
#
#                                               atmosphere
#  you look at that river                          0.00000
# gently flowing by                                0.00000
# you notice the leaves rustling with the wind     0.00000
# you hear the birds                               0.00497
# you hear the tree frogs                          0.00497

# %%
H.sort_values(by = 'solar', ascending = False)
# Out:
#                                                         ice  earth  movement  \
# and it resulted in the largest solar loan in th...  0.00000    0.0       0.0
# but in many parts of china it is already cheape...  0.00000    0.0       0.0
# pennsylvanias exercising leadership on solar po...  0.00000    0.0       0.0
# so my narrow interest is a way around these hig...  0.00000    0.0       0.0
# and we want to create jobs in solar and wind an...  0.00000    0.0       0.0
# ...                                                     ...    ...       ...
# and you know the number of those that disagreed...  0.00054    0.0       0.0
# and they took a big sample of   articles            0.00000    0.0       0.0
# there was a massive study of every scientific a...  0.00384    0.0       0.0
# actually not really                                 0.00000    0.0       0.0
# thank you                                           0.00000    0.0       0.0
#
#                                                     globalwarming  climate  \
# and it resulted in the largest solar loan in th...        0.00000      0.0
# but in many parts of china it is already cheape...        0.00000      0.0
# pennsylvanias exercising leadership on solar po...        0.00000      0.0
# so my narrow interest is a way around these hig...        0.00000      0.0
# and we want to create jobs in solar and wind an...        0.00000      0.0
# ...                                                           ...      ...
# and you know the number of those that disagreed...        0.40934      0.0
# and they took a big sample of   articles                  0.00000      0.0
# there was a massive study of every scientific a...        0.42051      0.0
# actually not really                                       0.00000      0.0
# thank you                                                 0.00000      0.0
#
#                                                       solar  atmosphere  \
# and it resulted in the largest solar loan in th...  0.72518     0.00000
# but in many parts of china it is already cheape...  0.61964     0.02857
# pennsylvanias exercising leadership on solar po...  0.53564     0.00000
# so my narrow interest is a way around these hig...  0.53564     0.00000
# and we want to create jobs in solar and wind an...  0.53564     0.00000
# ...                                                     ...         ...
# and you know the number of those that disagreed...  0.00000     0.00000
# and they took a big sample of   articles            0.00000     0.00000
# there was a massive study of every scientific a...  0.00000     0.00000
# actually not really                                 0.00000     0.00000
# thank you                                           0.00000     0.00000
#
#                                                             topic  movie
# and it resulted in the largest solar loan in th...          solar      2
# but in many parts of china it is already cheape...          solar      2
# pennsylvanias exercising leadership on solar po...          solar      1
# so my narrow interest is a way around these hig...          solar      2
# and we want to create jobs in solar and wind an...          solar      2
# ...                                                           ...    ...
# and you know the number of those that disagreed...  globalwarming      1
# and they took a big sample of   articles                     none      1
# there was a massive study of every scientific a...  globalwarming      1
# actually not really                                          none      1
# thank you                                                    none      2
#
# [1900 rows x 9 columns]

# %%
topic_list = []
for row, col in H.iterrows():
    #print(type(col))
    #if col == pd.Series([0, 0, 0, 0, 0, 0, 0]):
    if (col == 0).all():
        topic_list.append('none')
    else:
        topic_list.append(col[col == col.max()].index[0])
    #print(col)
#H['topic'] = topic_list

# %%
H['topic'] = topic_list

# %%
H.head()
# Out:
#                                               ice  earth  movement  \
#  you look at that river                       0.0    0.0       0.0
# gently flowing by                             0.0    0.0       0.0
# you notice the leaves rustling with the wind  0.0    0.0       0.0
# you hear the birds                            0.0    0.0       0.0
# you hear the tree frogs                       0.0    0.0       0.0
#
#                                               globalwarming  climate    solar  \
#  you look at that river                                 0.0  0.00000  0.00000
# gently flowing by                                       0.0  0.00000  0.00000
# you notice the leaves rustling with the wind            0.0  0.00000  0.17305
# you hear the birds                                      0.0  0.00224  0.00773
# you hear the tree frogs                                 0.0  0.00224  0.00773
#
#                                               atmosphere  topic
#  you look at that river                          0.00000   none
# gently flowing by                                0.00000   none
# you notice the leaves rustling with the wind     0.00000  solar
# you hear the birds                               0.00497  solar
# you hear the tree frogs                          0.00497  solar

# %%
# Add Movie Column
m1_len = [1] * len(movie1_list)
m2_len = [2] * len(movie2_list)
m12_len = m1_len + m2_len
H['movie'] = m12_len

H.head()
# Out:
#                                               ice  earth  movement  \
#  you look at that river                       0.0    0.0       0.0
# gently flowing by                             0.0    0.0       0.0
# you notice the leaves rustling with the wind  0.0    0.0       0.0
# you hear the birds                            0.0    0.0       0.0
# you hear the tree frogs                       0.0    0.0       0.0
#
#                                               globalwarming  climate    solar  \
#  you look at that river                                 0.0  0.00000  0.00000
# gently flowing by                                       0.0  0.00000  0.00000
# you notice the leaves rustling with the wind            0.0  0.00000  0.17305
# you hear the birds                                      0.0  0.00224  0.00773
# you hear the tree frogs                                 0.0  0.00224  0.00773
#
#                                               atmosphere  topic  movie
#  you look at that river                          0.00000   none      1
# gently flowing by                                0.00000   none      1
# you notice the leaves rustling with the wind     0.00000  solar      1
# you hear the birds                               0.00497  solar      1
# you hear the tree frogs                          0.00497  solar      1

# %%
# Table showing how much more of each category there is in each
H.groupby('movie')['topic'].value_counts()
# Out:
# movie  topic
# 1      none             455
#        atmosphere       135
#        ice               82
#        globalwarming     67
#        earth             61
#        solar             52
#        climate           46
#        movement           7
# 2      none             571
#        climate          119
#        atmosphere       112
#        solar             79
#        earth             43
#        globalwarming     41
#        ice               19
#        movement          11
# Name: topic, dtype: int64

# %%
print(len(movie1_list))
print(len(movie2_list))
# Out:
# 905
# 995

# %%
#H[H['topic'] == 'none'][-20:]

# %% [markdown]
# # Percentage amounts of each category in every row

# %%
H.head()
# Out:
#                                               ice  earth  movement  \
#  you look at that river                       0.0    0.0       0.0
# gently flowing by                             0.0    0.0       0.0
# you notice the leaves rustling with the wind  0.0    0.0       0.0
# you hear the birds                            0.0    0.0       0.0
# you hear the tree frogs                       0.0    0.0       0.0
#
#                                               globalwarming  climate    solar  \
#  you look at that river                                 0.0  0.00000  0.00000
# gently flowing by                                       0.0  0.00000  0.00000
# you notice the leaves rustling with the wind            0.0  0.00000  0.17310
# you hear the birds                                      0.0  0.00224  0.00773
# you hear the tree frogs                                 0.0  0.00224  0.00773
#
#                                               atmosphere  topic  movie
#  you look at that river                          0.00000   none      1
# gently flowing by                                0.00000   none      1
# you notice the leaves rustling with the wind     0.00000  solar      1
# you hear the birds                               0.00497  solar      1
# you hear the tree frogs                          0.00497  solar      1

# %% [markdown]
# # Timestamp

# %%
movie1_time = H[H['movie'] == 1]

# %%
# Inconvenient Truth
# An Inconvenient Truth is: 118 minutes, 7080 seconds
# Each "document" is around 7080/905 seconds, or 7.8 seconds

time_list = []

seconds = 0

for doc in range(0, len(movie1_time)):
    seconds += 7080/905
    time_list.append(round(seconds, 2))

movie1_time = H[H['movie'] == 1]
movie1_time['time'] = time_list
movie1_time['percent_time'] = [round(time/7080, 3)*100 for time in time_list]
movie1_time.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                                               ice  earth  movement  \
#  you look at that river                       0.0    0.0       0.0
# gently flowing by                             0.0    0.0       0.0
# you notice the leaves rustling with the wind  0.0    0.0       0.0
# you hear the birds                            0.0    0.0       0.0
# you hear the tree frogs                       0.0    0.0       0.0
#
#                                               globalwarming  climate    solar  \
#  you look at that river                                 0.0  0.00000  0.00000
# gently flowing by                                       0.0  0.00000  0.00000
# you notice the leaves rustling with the wind            0.0  0.00000  0.17305
# you hear the birds                                      0.0  0.00224  0.00773
# you hear the tree frogs                                 0.0  0.00224  0.00773
#
#                                               atmosphere  topic  movie   time  \
#  you look at that river                          0.00000   none      1   7.82
# gently flowing by                                0.00000   none      1  15.65
# you notice the leaves rustling with the wind     0.00000  solar      1  23.47
# you hear the birds                               0.00497  solar      1  31.29
# you hear the tree frogs                          0.00497  solar      1  39.12
#
#                                               percent_time
#  you look at that river                                0.1
# gently flowing by                                      0.2
# you notice the leaves rustling with the wind           0.3
# you hear the birds                                     0.4
# you hear the tree frogs                                0.6

# %%
def return_topic(df):
    
    if len(df['topic'].value_counts()) == 1:
        return(df['topic'].value_counts().index[0])
    
    elif df['topic'].value_counts().index[0] == 'none':
        return(df['topic'].value_counts().index[1])
    
    else:
        return(df['topic'].value_counts().index[0])

# %%
top_row = 0
bottom_row = 5

agg_topic_list = []

for df in range(0, 181):
    topic = return_topic(movie1_time.iloc[top_row:bottom_row, :])
    
    agg_topic_list.extend([topic] * 5)
    
    top_row += 5
    bottom_row += 5

# %%
#movie1_time['smoothed_group'].value_counts()

# %%
movie1_time['smoothed_group'] = agg_topic_list
movie1_time.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                               ice  earth  movement  \
#  you look at that river                       0.0    0.0       0.0
# gently flowing by                             0.0    0.0       0.0
# you notice the leaves rustling with the wind  0.0    0.0       0.0
# you hear the birds                            0.0    0.0       0.0
# you hear the tree frogs                       0.0    0.0       0.0
#
#                                               globalwarming  climate    solar  \
#  you look at that river                                 0.0  0.00000  0.00000
# gently flowing by                                       0.0  0.00000  0.00000
# you notice the leaves rustling with the wind            0.0  0.00000  0.17305
# you hear the birds                                      0.0  0.00224  0.00773
# you hear the tree frogs                                 0.0  0.00224  0.00773
#
#                                               atmosphere  topic  movie   time  \
#  you look at that river                          0.00000   none      1   7.82
# gently flowing by                                0.00000   none      1  15.65
# you notice the leaves rustling with the wind     0.00000  solar      1  23.47
# you hear the birds                               0.00497  solar      1  31.29
# you hear the tree frogs                          0.00497  solar      1  39.12
#
#                                               percent_time smoothed_group
#  you look at that river                                0.1          solar
# gently flowing by                                      0.2          solar
# you notice the leaves rustling with the wind           0.3          solar
# you hear the birds                                     0.4          solar
# you hear the tree frogs                                0.6          solar

# %%
movie1_time['smoothed_group'].value_counts()
# Out:
# atmosphere       250
# ice              200
# earth            120
# climate           95
# solar             95
# globalwarming     70
# none              65
# movement          10
# Name: smoothed_group, dtype: int64

# %%
movie2_time['smoothed_group'].value_counts()
# Out:
# climate          320
# atmosphere       195
# solar            160
# earth            110
# globalwarming     80
# none              75
# ice               30
# movement          25
# Name: smoothed_group, dtype: int64

# %%
topics = list(movie1_time.smoothed_group.value_counts().index)
cumcounts = np.zeros((len(topics),len(movie1_time)))

## Vinny's amazing code that counts
for i in range(len(movie1_time)):
    cumcounts[:,i] = cumcounts[:,i-1]
    k = topics.index(movie1_time.smoothed_group[i])
    cumcounts[k,i]+=1

# cumcounts[2,200]

# %%
import seaborn as sns
sns.set(font_scale = 1.5)
import matplotlib.pyplot as plt
# %matplotlib inline

#sns.set_style("whitegrid", {'axes.grid' : False, 'axes.facecolor':'white'} )

# %%
plt.figure(figsize=(16, 10))

ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[0], label = 'atmosphere')
ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[1], label = 'ice')
ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[2], label = 'solar')
ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[3], label = 'earth')
ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[4], label = 'globalwarming')
ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[5], label = 'climate')
#ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[6], label = 'none')
ax = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[7], label = 'movement')

plt.rcParams["axes.labelsize"] = 20
plt.rcParams['axes.labelpad'] = 40 
ax.set(xlabel='Percentage Through Movie', ylabel='Number of Sentences')

#ax.grid(False)
#sns.despine(bottom = True, left = True);
#ax.right_ax(False);
# Out:
# [Text(0, 0.5, 'Number of Sentences'), Text(0.5, 0, 'Percentage Through Movie')]

# %%
plt.figure(figsize=(16, 10))
ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[0]/cumcounts[0,-1], label = 'atmosphere')
ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[1]/cumcounts[1,-1], label = 'ice')
ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[2]/cumcounts[2,-1], label = 'solar')
ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[3]/cumcounts[3,-1], label = 'earth')
ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[4]/cumcounts[4,-1], label = 'globalwarming')
ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[5]/cumcounts[5,-1], label = 'climate')
#ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[6]/cumcounts[6,-1], label = 'none')
ax2 = sns.lineplot(x = movie1_time['percent_time'], y = cumcounts[7]/cumcounts[7,-1], label = 'movement')

# %%
#cumcounts[5]/cumcounts[2,-1]

# %% [markdown]
# # Timestamp for Inconvenient Sequel

# %%
# Inconvenient Sequel
movie2_time = H[H['movie'] == 2]
movie2_time.head()
# Out:
#                                                         ice    earth  \
#                          algores movie an incon...  0.00019  0.00000
# sea levels may rise  feet is absurd                 0.00485  0.00000
# but this is algore                                  0.00000  0.00000
# he always goes down the road of hyperbole           0.00000  0.00000
# not only is he losing the argument on climatech...  0.00000  0.00566
#
#                                                     movement  globalwarming  \
#                          algores movie an incon...       0.0        0.01245
# sea levels may rise  feet is absurd                      0.0        0.00074
# but this is algore                                       0.0        0.00000
# he always goes down the road of hyperbole                0.0        0.00000
# not only is he losing the argument on climatech...       0.0        0.01178
#
#                                                     climate    solar  \
#                          algores movie an incon...  0.00275  0.00186
# sea levels may rise  feet is absurd                 0.00000  0.00469
# but this is algore                                  0.00000  0.00001
# he always goes down the road of hyperbole           0.00000  0.00000
# not only is he losing the argument on climatech...  0.03654  0.00539
#
#                                                     atmosphere          topic  \
#                          algores movie an incon...     0.00000  globalwarming
# sea levels may rise  feet is absurd                    0.00462            ice
# but this is algore                                     0.00008     atmosphere
# he always goes down the road of hyperbole              0.00000           none
# not only is he losing the argument on climatech...     0.00000        climate
#
#                                                     movie
#                          algores movie an incon...      2
# sea levels may rise  feet is absurd                     2
# but this is algore                                      2
# he always goes down the road of hyperbole               2
# not only is he losing the argument on climatech...      2

# %%
# The Inconvenient Sequel is: 1 hour and 39 minutes, 5940 seconds
# Each "document" is around 7080/905 seconds, or 7.8 seconds

time_list2 = []
seconds = 0

for doc in range(0, len(movie2_time)):
    seconds += ((60+39)*60) / len(movie2_time)
    time_list2.append(round(seconds, 2))

# %%
movie2_time = H[H['movie'] == 2]
movie2_time['time'] = time_list2
movie2_time['percent_time'] = [round(time/((60+39)*60), 4)*100 for time in time_list2]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
movie2_time.tail()
# Out:
#                                                     ice    earth  movement  \
# and we too in this movement will encounter a se...  0.0  0.00000   0.42323
# the great american poet wallace stevens in the ...  0.0  0.00604   0.00000
# and on that yes the future world depends            0.0  0.00000   0.00000
#  byebye guys                                        0.0  0.00000   0.00000
# thank you                                           0.0  0.00000   0.00000
#
#                                                     globalwarming  climate  \
# and we too in this movement will encounter a se...        0.00000  0.00000
# the great american poet wallace stevens in the ...        0.01929  0.02210
# and on that yes the future world depends                  0.01908  0.02165
#  byebye guys                                              0.00000  0.00000
# thank you                                                 0.00000  0.00000
#
#                                                       solar  atmosphere  \
# and we too in this movement will encounter a se...  0.00000         0.0
# the great american poet wallace stevens in the ...  0.00571         0.0
# and on that yes the future world depends            0.00518         0.0
#  byebye guys                                        0.00000         0.0
# thank you                                           0.00000         0.0
#
#                                                        topic  movie     time  \
# and we too in this movement will encounter a se...  movement      2  5916.12
# the great american poet wallace stevens in the ...   climate      2  5922.09
# and on that yes the future world depends             climate      2  5928.06
#  byebye guys                                            none      2  5934.03
# thank you                                               none      2  5940.00
#
#                                                     percent_time
# and we too in this movement will encounter a se...          99.6
# the great american poet wallace stevens in the ...          99.7
# and on that yes the future world depends                    99.8
#  byebye guys                                                99.9
# thank you                                                  100.0

# %%
# smoothed_group
top_row = 0
bottom_row = 5

agg_topic_list2 = []

for df in range(0, 199):
    topic = return_topic(movie2_time.iloc[top_row:bottom_row, :])
    
    agg_topic_list2.extend([topic] * 5)
    
    top_row += 5
    bottom_row += 5
    
movie2_time['smoothed_group'] = agg_topic_list2
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
(movie2_time['smoothed_group'].value_counts()/len(movie2_time)).index
# Out:
# Index(['climate', 'atmosphere', 'solar', 'earth', 'globalwarming', 'none',
#        'ice', 'movement'],
#       dtype='object')

# %%
sns.barplot()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
movie2_time.tail()
# Out:
#                                                     ice    earth  movement  \
# and we too in this movement will encounter a se...  0.0  0.00000   0.42323
# the great american poet wallace stevens in the ...  0.0  0.00604   0.00000
# and on that yes the future world depends            0.0  0.00000   0.00000
#  byebye guys                                        0.0  0.00000   0.00000
# thank you                                           0.0  0.00000   0.00000
#
#                                                     globalwarming  climate  \
# and we too in this movement will encounter a se...        0.00000  0.00000
# the great american poet wallace stevens in the ...        0.01929  0.02210
# and on that yes the future world depends                  0.01908  0.02165
#  byebye guys                                              0.00000  0.00000
# thank you                                                 0.00000  0.00000
#
#                                                       solar  atmosphere  \
# and we too in this movement will encounter a se...  0.00000         0.0
# the great american poet wallace stevens in the ...  0.00571         0.0
# and on that yes the future world depends            0.00518         0.0
#  byebye guys                                        0.00000         0.0
# thank you                                           0.00000         0.0
#
#                                                        topic  movie     time  \
# and we too in this movement will encounter a se...  movement      2  5916.12
# the great american poet wallace stevens in the ...   climate      2  5922.09
# and on that yes the future world depends             climate      2  5928.06
#  byebye guys                                            none      2  5934.03
# thank you                                               none      2  5940.00
#
#                                                     percent_time  \
# and we too in this movement will encounter a se...          99.6
# the great american poet wallace stevens in the ...          99.7
# and on that yes the future world depends                    99.8
#  byebye guys                                                99.9
# thank you                                                  100.0
#
#                                                    smoothed_group
# and we too in this movement will encounter a se...        climate
# the great american poet wallace stevens in the ...        climate
# and on that yes the future world depends                  climate
#  byebye guys                                              climate
# thank you                                                 climate

# %%
topics2 = list(movie2_time.smoothed_group.value_counts().index)
cumcounts2 = np.zeros((len(topics2),len(movie2_time)))

## Vinny's amazing code that counts
for i in range(len(movie2_time)):
    cumcounts2[:,i] = cumcounts2[:,i-1]
    k2 = topics2.index(movie2_time.smoothed_group[i])
    cumcounts2[k2,i]+=1

#topics2

# %%
topics2
# Out:
# ['climate',
#  'atmosphere',
#  'solar',
#  'earth',
#  'globalwarming',
#  'none',
#  'ice',
#  'movement']

# %%
plt.figure(figsize=(16, 10))

ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[0], label = 'climate')
ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[1], label = 'atmosphere')
ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[2], label = 'solar')
ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[3], label = 'earth')
ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[4], label = 'globalwarming')
#ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[5], label = 'narration')
ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[6], label = 'ice')
ax = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[7], label = 'movement')

plt.rcParams["axes.labelsize"] = 25
plt.rcParams['axes.labelpad'] = 40 
ax.set(xlabel='Percentage Through Movie', ylabel='Number of Sentences');
#ax.set_title(' Throughout Movie', fontsize = 35, pad=40);

# %%
plt.figure(figsize=(16, 10))
ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[0]/cumcounts2[0,-1], label = 'climate')
ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[1]/cumcounts2[1,-1], label = 'atmosphere')
ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[2]/cumcounts2[2,-1], label = 'solar')
ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[3]/cumcounts2[3,-1], label = 'earth')
ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[4]/cumcounts2[4,-1], label = 'globalwarming')
#ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[5]/cumcounts2[5,-1], label = 'narration')
ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[6]/cumcounts2[6,-1], label = 'ice')
ax2 = sns.lineplot(x = movie2_time['percent_time'], y = cumcounts2[7]/cumcounts2[7,-1], label = 'movement')

plt.rcParams["axes.labelsize"] = 25
ax2.set(xlabel='Percentage Through Movie', ylabel='Percentage of Each Topic');
